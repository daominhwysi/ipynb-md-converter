# %% [markdown]
# # Sample Jupyter Notebook
# This is a sample notebook loaded into the **IPYNB Terminal Converter**.
# It contains formatting, headers, and code execution outputs.

# %%
import numpy as np
print('Initializing neural engine...')
for epoch in range(3):
    print(f'Epoch {epoch+1}/5: loss={0.456/(epoch+1):.3f}')
print('Training completed successfully.')
# Out:
# Initializing neural engine...
# Epoch 1/5: loss=0.456, accuracy=0.882
# Epoch 2/5: loss=0.213, accuracy=0.941
# Epoch 3/5: loss=0.102, accuracy=0.978
# Training completed successfully.

# %% [markdown]
# ## Output Visualization
# Here is a markdown block preceding a matplotlib chart cell output containing base64 data.

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()
